# %%
import pandas as pd
import os
from bing_image_downloader import downloader as dl
data = pd.read_csv('FCi Breeds.csv')

# %%
for dog in data['name']:
    
    if dog.upper().startswith('O'):
    
        if 'dog' not in dog.lower():
            name = dog.lower() + ' dog'

        else:
            name = dog.lower()

        if name not in os.listdir():
            print(name.upper(), '\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n')

            dl.download(query=name, 
                        limit=35, 
                        output_dir=r'A:\Python Projects\Dog-Breeds-Dataset',
                        adult_filter_off=False)
# Out:
# OLD DANISH POINTING DOG
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [%] Downloading Images to A:\Python Projects\Dog-Breeds-Dataset\old danish pointing dog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.101dogbreeds.com/wp-content/uploads/2016/06/Old-Danish-Pointer-Dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://myanimals.com/wp-content/uploads/2020/04/puppy-danish-pointer.jpg?auto=webp&amp;quality=45&amp;width=750&amp;crop=16:9
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.ooreka.fr/public/image/3-308527-7529-full-13599483.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.dogzone.com/images/breeds/old-danish-pointer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/89/e0/d5/89e0d57b84508589fe1dbb69556c898e.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://skk.se/globalassets/nku/filer/images/nordic-breeds/gammel-dansk-honsehund.jpg
# [!] Issue getting: https://skk.se/globalassets/nku/filer/images/nordic-breeds/gammel-dansk-honsehund.jpg
# [!] Error:: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
# [%] Downloading Image #6 from https://i.pinimg.com/736x/05/a3/92/05a3929534123cd592f34a6492ef0db6--danishes-bird.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://nationalpurebreddogday.com/wp-content/uploads/2019/08/Screen-Shot-2019-08-29-at-3.32.46-PM.png
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://c8.alamy.com/comp/GDFFMF/old-danish-pointing-dog-GDFFMF.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://i.pinimg.com/originals/0d/9d/46/0d9d469f759ff84c57fb031e1c0539ea.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://www.livelife.guide/wp-content/uploads/2018/04/Old-Danish-Pointer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://www.101dogbreeds.com/wp-content/uploads/2016/06/Old-Danish-Chicken-Dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://c8.alamy.com/comp/GDFFMH/old-danish-pointing-dog-GDFFMH.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://i.pinimg.com/474x/19/fa/3e/19fa3efeadbdabef227d5195c7d9ab3b--dog-breeds-danishes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://www.101dogbreeds.com/wp-content/uploads/2016/06/Old-Danish-Bird-Dog.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.alldogstickers.com/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/o/l/old_danish_pointing_dog-101.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://www.mascotarios.org/wp-content/gallery/antiguo-perro-de-muestra-danes/antiguo-perro-de-muestra-danes.jpg
